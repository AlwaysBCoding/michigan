# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
st_clair_president = pd.read_csv('./st-clair-president.txt')
st_clair_straight_party = pd.read_csv('./st-clair-straight-party.txt')

# %%
st_clair_straight_party
# Out:
#                       precinct_name  registered  votes_cast turnout  dem  rep  \
# 0           Algonac City Precinct 1        1538        1134  73.73%  168  473
# 1           Algonac City Precinct 2        1996        1345  67.38%  210  565
# 2        Berlin Township Precinct 1        2521        1996  79.17%  216  845
# 3      Brockway Township Precinct 1        1611        1187  73.68%  121  545
# 4   Burtchville Township Precinct 2        1606        1192  74.22%  181  385
# ..                              ...         ...         ...     ...  ...  ...
# 65        St. Clair City Precinct 3        1501        1087  72.42%  205  367
# 66    St. Clair Township Precinct 1        3075        2472  80.39%  335  846
# 67    St. Clair Township Precinct 2        2839        2158  76.01%  258  760
# 68        Wales Township Precinct 1        2666        2019  75.73%  239  646
# 69             Yale City Precinct 1        1402         931  66.41%  149  355
#
#     lib  ust  wcp  grn  nlp  sp_total  percentage_republican
# 0     4    0    5    1    0       651               0.726575
# 1     3    1    3    3    1       786               0.718830
# 2     4    0    2    1    0      1068               0.791199
# 3     0    0    0    0    0       666               0.818318
# 4     3    0    4    2    0       575               0.669565
# ..  ...  ...  ...  ...  ...       ...                    ...
# 65    4    0    3    3    0       582               0.630584
# 66    3    1    6    0    1      1192               0.709732
# 67    2    1    4    2    1      1028               0.739300
# 68    6    4    6    2    1       904               0.714602
# 69    5    4    6    1    0       520               0.682692
#
# [70 rows x 13 columns]

# %%
st_clair_straight_party['sp_total'] = (
    st_clair_straight_party['dem'] +
    st_clair_straight_party['rep'] +
    st_clair_straight_party['lib'] +
    st_clair_straight_party['ust'] +
    st_clair_straight_party['wcp'] +
    st_clair_straight_party['grn'] +
    st_clair_straight_party['nlp']
)

st_clair_straight_party['percentage_republican'] = st_clair_straight_party['rep'] / st_clair_straight_party['sp_total']

# %%
st_clair_president['total_votes'] = (
    st_clair_president['biden'] +
    st_clair_president['trump']
)
